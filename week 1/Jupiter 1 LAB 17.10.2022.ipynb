# %% [markdown]
# #  Vacation preference

# %% [markdown]
# italic:
# The purpose of this notebook is to introduce the vacation preference of John.

# %% [markdown]
# ![Paris.jpg](attachment:Paris.jpg)

# %% [markdown]
# ![Nord%20See.jpg](attachment:Nord%20See.jpg)

# %% [markdown]
# ![Alps.jpg](attachment:Alps.jpg)

# %% [markdown]
# John likes to
# - Hike
# - surf
# - city tour

# %%
from IPython.core.display import HTML

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/watch?v=8wevjW5hQG0&t=120s" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/watch?v=8wevjW5hQG0&t=120s" frameborder="0" allowfullscreen></iframe>

# %%
jupyter nbconvert Jupiter 1 LAB 17.10.2022.ipynb --to slides --post serve
# Out:
#   Input In [47]
#     jupyter nbconvert Jupiter 1 LAB 17.10.2022.ipynb --to slides --post serve
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## guessing your favourite place

# %%
x=input("Please enter your name: " )

import random

places = ['Nord See', 'Boden See', 'Alpes', 'Rome',"Paris","London","Lisbon","Madrid"]
print("Hello", x,", Is your favourite place to have a holiday would be:",random.choice(places),"?")
# Out:
# Please enter your name: moran
# Hello moran , Is your favourite place to have a holiday would be: Boden See ?
